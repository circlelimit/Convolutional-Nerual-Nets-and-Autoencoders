# %% [markdown]
# # Project 2 part A

# %% [markdown]
# ## 1. running with SGD

# %% [markdown]
# Training and testing model...

# %%
method = 'sgd'
exec(open('Project_2a_13_nov.py').read())
time.ctime()
# Out:
# C:\Users\Melissa\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: UserWarning: pool_2d() will have the parameter ignore_border default value changed to True (currently False). To have consistent behavior with all Theano version, explicitly add the parameter ignore_border=True. On the GPU, using ignore_border=True is needed to use cuDNN. When using ignore_border=False and not using cuDNN, the only GPU combination supported is when `ws == stride and pad == (0, 0) and mode == 'max'`. Otherwise, the convolution will be executed on CPU.
# ...

# %% [markdown]
# Plotiing test accuracy and train cost against epochs...

# %%
pylab.figure()
pylab.plot(range(noIters), a1, label='sgd')
pylab.xlabel('epochs')
pylab.ylabel('test accuracy')
pylab.legend(loc='lower right')
pylab.title('Test accuracy against epochs using mini batch gradient descent algorithm')
pylab.savefig('figure_2a_test_accuracy_1.png')


pylab.figure()
pylab.plot(range(noIters), c1, label='sgd')
pylab.xlabel('epochs')
pylab.ylabel('train cost')
pylab.legend(loc='lower right')
pylab.title('Train cost against epochs using mini batch gradient descent algorithm')
pylab.savefig('figure_2a_train_cost_1.png')

pylab.show()
time.ctime()
# Out:
# 'Mon Nov 13 21:51:58 2017'

# %% [markdown]
# ## 2. running with SGD with momentum

# %% [markdown]
# Training and testing model...

# %%
method = 'sgd with momentum'
exec(open('Project_2a_13_nov.py').read())
time.ctime()
# Out:
# C:\Users\Melissa\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: UserWarning: pool_2d() will have the parameter ignore_border default value changed to True (currently False). To have consistent behavior with all Theano version, explicitly add the parameter ignore_border=True. On the GPU, using ignore_border=True is needed to use cuDNN. When using ignore_border=False and not using cuDNN, the only GPU combination supported is when `ws == stride and pad == (0, 0) and mode == 'max'`. Otherwise, the convolution will be executed on CPU.
# ...

# %% [markdown]
# Plotiing test accuracy and train cost against epochs...

# %%
pylab.figure()
pylab.plot(range(noIters), a2, label='sgd with momentum')
pylab.xlabel('epochs')
pylab.ylabel('test accuracy')
pylab.legend(loc='lower right')
pylab.title('Test accuracy against epochs using mini batch gradient descent algorithm with momentum parameter')
pylab.savefig('figure_2a_test_accuracy_2.png')


pylab.figure()
pylab.plot(range(noIters), c2, label='sgd with momentum')
pylab.xlabel('epochs')
pylab.ylabel('train cost')
pylab.title('Train cost against epochs using mini batch gradient descent algorithm with momentum parameter')
pylab.legend(loc='lower right')

pylab.savefig('figure_2a_train_cost_2.png')

pylab.show()
time.ctime()
# Out:
# 'Mon Nov 13 22:02:54 2017'

# %% [markdown]
# ## 3. running with RMSprop

# %% [markdown]
# Training and testing model...

# %%
method = 'RMSprop'
exec(open('Project_2a_13_nov.py').read())
time.ctime()
# Out:
# C:\Users\Melissa\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: UserWarning: pool_2d() will have the parameter ignore_border default value changed to True (currently False). To have consistent behavior with all Theano version, explicitly add the parameter ignore_border=True. On the GPU, using ignore_border=True is needed to use cuDNN. When using ignore_border=False and not using cuDNN, the only GPU combination supported is when `ws == stride and pad == (0, 0) and mode == 'max'`. Otherwise, the convolution will be executed on CPU.
# ...

# %% [markdown]
# Plotiing test accuracy and train cost against epochs...

# %%
pylab.figure()
pylab.plot(range(noIters), a3, label='RMSprop')
pylab.xlabel('epochs')
pylab.ylabel('test accuracy')
pylab.legend(loc='lower right')
pylab.title('Test accuracy against epochs using RMSProp algorithm')
pylab.savefig('figure_2a_test_accuracy_3.png')


pylab.figure()
pylab.plot(range(noIters), c3, label='RMSprop')
pylab.xlabel('epochs')
pylab.ylabel('train cost')
pylab.legend(loc='lower right')
pylab.title('Train cost against epochs using RMSProp algorithm')
pylab.savefig('figure_2a_train_cost_3.png')
           
pylab.show()
time.ctime()
# Out:
# 'Mon Nov 13 22:14:07 2017'

# %% [markdown]
# ## 4. Comparing SGD, SGD with momentum and RMSprop results

# %%
pylab.figure()
pylab.plot(range(noIters), a1, label='sgd')
pylab.plot(range(noIters), a2, label='sgd with momentum')
pylab.plot(range(noIters), a3, label='RMSprop')
pylab.xlabel('epochs')
pylab.ylabel('test accuracy')
pylab.legend(loc='lower right')
pylab.savefig('figure_2a_test_accuracy_all.png')


pylab.figure()
pylab.plot(range(noIters), c1, label='sgd')
pylab.plot(range(noIters), c2, label='sgd with momentum')
pylab.plot(range(noIters), c3, label='RMSprop')
pylab.xlabel('epochs')
pylab.ylabel('train cost')
pylab.legend(loc='lower right')
pylab.savefig('figure_2a_train_cost_all.png')

pylab.show()
time.ctime()
# Out:
# 'Mon Nov 13 22:14:08 2017'
